# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.6'

# %%
df=pd.read_csv("https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/main/cohorts/2026/data/car_fuel_efficiency_2026.csv")

# %%
df.head()
# Out:
#    model_year  origin fuel_type         drivetrain  num_doors  \
# 0        2006  Europe  Gasoline  Front-wheel drive          4
# 1        2008  Europe    Diesel  Front-wheel drive          4
# 2        1996    Asia  Gasoline  Front-wheel drive          5
# 3        1989  Europe  Gasoline  Front-wheel drive          4
# 4        1994     USA    Diesel  Front-wheel drive          3
#
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                 2180              6       243.0            3870
# 1                 2390              6       272.0            4210
# 2                 2320              6       267.0            4240
# 3                 2130              6       258.0            4490
# 4                 2580              7       304.0            4510
#
#    acceleration  fuel_efficiency_mpg
# 0           NaN                 31.9
# 1           NaN                 31.3
# 2          17.3                 27.5
# 3          18.7                 28.5
# ...

# %%
df.shape[0]
# Out:
# 10000

# %%
df.fuel_type.nunique()
# Out:
# 3

# %%
df.nunique()
# Out:
# model_year              50
# origin                   3
# fuel_type                3
# drivetrain               3
# num_doors                4
# engine_displacement    127
# num_cylinders            5
# horsepower             153
# vehicle_weight         176
# acceleration            93
# fuel_efficiency_mpg    188
# dtype: int64

# %%
df.isnull().sum()
# Out:
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors                0
# engine_displacement      0
# num_cylinders            0
# horsepower             877
# vehicle_weight           0
# acceleration           264
# fuel_efficiency_mpg      0
# dtype: int64

# %%
(df.isnull().sum() > 0).sum()
# Out:
# np.int64(2)

# %%
df.groupby('origin')['fuel_efficiency_mpg'].agg(['min', 'mean', 'max'])
# Out:
#          min       mean   max
# origin
# Asia    21.3  30.741015  41.2
# Europe  20.7  30.552675  39.4
# USA     19.8  29.097739  38.2

# %%
df.query("origin == 'Asia'")['fuel_efficiency_mpg'].max()
# Out:
# np.float64(41.2)

# %%
median_before = df['horsepower'].median()
print(median_before)
# Out:
# 254.0

# %%
most_frequent = df['horsepower'].mode()[0]
print(most_frequent)
# Out:
# 252.0

# %%
df['horsepower'] = df['horsepower'].fillna(most_frequent)

# %%
median_after = df['horsepower'].median()
print(median_after)
# Out:
# 252.0

# %% [markdown]
# select cars from Asia origin

# %%
cars_from_asia = df[df['origin']=='Asia']

# %% [markdown]
# Select only columns vehicle_weight and model_year

# %%
df_asia_filtered = cars_from_asia[['vehicle_weight', 'model_year']]

# %% [markdown]
# Select the first 7 values

# %%
df_asia_reduced = df_asia_filtered.iloc[:7, :]
